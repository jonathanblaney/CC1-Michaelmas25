# %%
# !pip install gensim
# Out:
# Collecting gensim
#   Downloading gensim-4.4.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (8.4 kB)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.12/dist-packages (from gensim) (2.0.2)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from gensim) (1.16.3)
# Requirement already satisfied: smart_open>=1.8.1 in /usr/local/lib/python3.12/dist-packages (from gensim) (7.5.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from smart_open>=1.8.1->gensim) (2.0.1)
# Downloading gensim-4.4.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (27.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.9/27.9 MB 73.7 MB/s eta 0:00:00
# Installing collected packages: gensim
# Successfully installed gensim-4.4.0

# %%
import re

import gensim
from gensim.models import Word2Vec

# %% [markdown]
# Get the text of *Moby Dick*.

# %%
# !wget https://raw.githubusercontent.com/jonathanblaney/CC1-Michaelmas25/refs/heads/main/week6-AI/moby-dick.txt
# Out:
# --2025-11-22 18:12:07--  https://raw.githubusercontent.com/jonathanblaney/CC1-Michaelmas25/refs/heads/main/week6-AI/moby-dick.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1276570 (1.2M) [text/plain]
# Saving to: ‘moby-dick.txt’
#
# moby-dick.txt       100%[===================>]   1.22M  --.-KB/s    in 0.02s
#
# 2025-11-22 18:12:08 (49.8 MB/s) - ‘moby-dick.txt’ saved [1276570/1276570]

# %%
with open('moby-dick.txt', 'r') as f:
  text = f.read()

# %% [markdown]
# Delete new lines.

# %%
text = text.replace("\n", " ")

# %% [markdown]
# Normalise the text as lower case and delete punctuation.

# %%
text = text.lower()
text = re.sub(r"[%&'()*+—,./:;?_’“”-]", "", text)

# %% [markdown]
# Split the text on spaces into a list.

# %%
words = text.split()

# %% [markdown]
# Word2Vec expects multiple documents, so to do *Moby Dick* on its own we'll split it into two lists. It would make more sense to split it into chapters, but that would take more data work.

# %%
len(words)
# Out:
# 215634

# %%
moby1 = words[:100_000]
moby2 = words[100_001:]

# %%
moby_all = []
moby_all.append(moby1)
moby_all.append(moby2)

# %%
# train the model
model = Word2Vec(sentences=moby_all, window=5, min_count=3, workers=4, epochs=5, sg=1)

# save the model
model.save("word2vec.model")

# %%
model = Word2Vec.load("word2vec.model")

# %% [markdown]
# Now we can query the word embeddings of *Moby Dick*.

# %%
model.wv.most_similar('ship', topn=20)
# Out:
# [('whaling', 0.9989882707595825),
#  ('line', 0.9989106059074402),
#  ('side', 0.9988850355148315),
#  ('day', 0.9988816380500793),
#  ('harpoon', 0.9988505244255066),
#  ('through', 0.9987950921058655),
#  ('boats', 0.998790442943573),
#  ('their', 0.9987748265266418),
#  ('sperm', 0.9987521171569824),
#  ('fish', 0.998691976070404),
#  ('ocean', 0.9986862540245056),
#  ('three', 0.9986821413040161),
#  ('back', 0.9986633658409119),
#  ('right', 0.9985581040382385),
#  ('own', 0.9984970688819885),
#  ('air', 0.998495876789093),
#  ('away', 0.9984713792800903),
#  ('word', 0.9984634518623352),
#  ('hand', 0.9984161257743835),
#  ('off', 0.998406708240509)]
